# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Asri Nur Azizah
# - **Email:** asriazizah.0994@gmail.com
# - **ID Dicoding:** Asri Azizah

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# **SMART Question** adalah sebuah framework untuk merumuskan pertanyaan secara terstruktur agar memeperoleh informasi yang mendalam.
#
# * **Spesific (Spesifik)**
#   * Pertanyaan harus jelas, fokus pada sebuah topik tertentu, dan tidak bermakna ganda. Hindari pertanyaan yang terlalu luas.
#     * Salah: Bagaimana cara meningkatkan penjualan?
#     * Benar: Faktor apa saja yang memengaruhi penurunan penjualan produk kategori elektronik di wilayah Jakarta selama kuartal terakhir?
# * **Measurable (Terukur)**
#   * Pertanyaan harus bisa dijawab dengan angka atau matrix yang konkret, harus tahu apa yang akan dihitung.
#     * Salah: Apakah pelanggan senang dengan layanan kita?
#     * Benar: Berapa skor rata-rata Customer Satisfaction untuk layanan purna jual bulan ini dibandingkan bulan lalu?
# * **Action-Oriented (Berorientasi Aksi)**
#   * Hasil dari pertanyaan harus bisa memberikan arahan untuk melakukan tindakan nyata. Jika pertanyaan terjawab, stakeholder harus tahu apa langkah selanjutnya.
#     * Salah: Mengapa orang suka berbelanja?
#     * Benar: Fitur apa pada aplikasi yang paling sering digunakan sebelum pengguna memutuskan untuk melakukan checkout?
# * **Relevant (Relevan)**
#   * Hasil dari pertanyaan harus sejalan dengan tujuan utama bisnis atau masalah yang sedang dihadapi.
#     * Salah: Menanyakan tentang stok gudang saat masalah utamanya adalah efektivitas kampanye media sosial.
#     * Benar: Apakah kampanye iklan di Instagram memberikan Return on Ad Spend (ROAS) yang lebih tinggi dibandingkan iklan di TikTok?
# * **Time-bound (Terikat Waktu)**
#   * Pertanyaan harus ada batasan waktu yang jelas agar analisis memiliki konteks yang tepat.
#     * Salah: Berapa banyak pengguna baru kita?
#     * Benar: Berapa tingkat pertumbuhan pengguna baru secara bulanan (Month-over-Month) sepanjang tahun 2025?

# %% [markdown]
# **Contoh pertanyaan bisnis yang memenuhi seluruh elemen SMART**
#
# ***"Faktor apa saja yang memengaruhi penurunan conversion rate pada pengguna aplikasi Android di wilayah Jabodetabek sebesar 5% selama periode Flash Sale Maret 2026?"***
#
# Keterangan:
#
# - **Specific**: Fokus pada "penurunan conversion rate" untuk "aplikasi Android" di "Jabodetabek". Bukan sekadar penjualan turun.
# - **Measurable**: Ada angka konkret yang ingin dianalisis, yaitu penurunan sebesar "5%".
# - **Action-Oriented**: Dengan mengetahui faktor penyebabnya misalnya bug pada versi Android tertentu atau kendala logistik di Jabodetabek, tim bisa langsung melakukan perbaikan teknis atau operasional.
# - **Relevant**: Penurunan konversi saat Flash Sale adalah masalah kritis bagi bisnis retail/e-commerce.
# - **Time-bound**: Dibatasi pada periode spesifik "Flash Sale Maret 2026".

# %% [markdown]
# - **Pertanyaan 1:** Bagaimana tren rata-rata konsentrasi PM2.5 pada 12 stasiun pemantauan kualitas udara di Beijing selama periode Maret 2013 hingga Februari 2017, dan stasiun mana yang memiliki tingkat PM2.5 tertinggi sehingga perlu menjadi prioritas pengendalian polusi?
#
# Keterangan :
# *   Specific : Fokus pada PM2.5 dan 12 stasiun pemantauan.
# *   Measurable : Mengukur rata-rata PM2.5.
# *   Action-Oriented : Menentukan area prioritas pengendalian polusi.
# *   Relevant : PM2.5 merupakan indikator utama kualitas udara.
# *   Time-bound : Maret 2013 hingga Februari 2017.
#
# - **Pertanyaan 2:** Sejauh mana faktor meteorologi (suhu, tekanan udara, curah hujan, dan kecepatan angin) memengaruhi konsentrasi PM2.5 di Beijing selama periode Maret 2013 hingga Februari 2017, sehingga dapat digunakan untuk mendukung strategi mitigasi polusi udara?
# Keterangan :
# *   Specific : Fokus pada hubungan faktor cuaca dengan PM2.5.
# *   Measurable : Menggunakan korelasi atau analisis statistik.
# *   Action-Oriented : Membantu perencanaan mitigasi polusi.
# *   Relevant : Kondisi cuaca sangat memengaruhi penyebaran polutan.
# *   Time-bound : Maret 2013 hingga Februari 2017.

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# #### Load df ...

# %%
Aotizhongxin_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Aotizhongxin.csv")
Aotizhongxin_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0
# 1          2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0
# 2          3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0
# 3          4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0
# 4          5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   12.0  29.0   5.0  35.0  400.0  95.0
# 35060  35061  2017      2   28    20   13.0  37.0   7.0  45.0  500.0  81.0
# 35061  35062  2017      2   28    21   16.0  37.0  10.0  66.0  700.0  58.0
# 35062  35063  2017      2   28    22   21.0  44.0  12.0  87.0  700.0  35.0
# 35063  35064  2017      2   28    23   19.0  31.0  10.0  79.0  600.0  42.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Changping_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Changping.csv")
Changping_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0
# 1          2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0
# 2          3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0
# 3          4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0
# 4          5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   28.0  47.0   4.0  14.0  300.0   NaN
# 35060  35061  2017      2   28    20   12.0  12.0   3.0  23.0  500.0  64.0
# 35061  35062  2017      2   28    21    7.0  23.0   5.0  17.0  500.0  68.0
# 35062  35063  2017      2   28    22   11.0  20.0   3.0  15.0  500.0  72.0
# 35063  35064  2017      2   28    23   20.0  25.0   6.0  28.0  900.0  54.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# ...

# %%
Dingling_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Dingling.csv")
Dingling_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO     O3  \
# 0          1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0   82.0
# 1          2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0   80.0
# 2          3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0   79.0
# 3          4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0   79.0
# 4          5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0   81.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...  ...    ...    ...
# 35059  35060  2017      2   28    19   11.0  11.0  2.0  2.0  200.0   99.0
# 35060  35061  2017      2   28    20   13.0  13.0  2.0  2.0  200.0  101.0
# 35061  35062  2017      2   28    21    9.0  14.0  2.0  2.0  200.0  102.0
# 35062  35063  2017      2   28    22   10.0  12.0  2.0  2.0  200.0   97.0
# 35063  35064  2017      2   28    23   13.0  16.0  4.0  9.0  500.0   74.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Dongsi_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Dongsi.csv")
Dongsi_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0   3.0  17.0   300.0  89.0
# 1          2  2013      3    1     1    4.0   4.0   3.0  16.0   300.0  88.0
# 2          3  2013      3    1     2    7.0   7.0   NaN  17.0   300.0  60.0
# 3          4  2013      3    1     3    3.0   3.0   5.0  18.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0   7.0   NaN   200.0  84.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  51.0   3.0  29.0   400.0  73.0
# 35060  35061  2017      2   28    20   18.0  45.0   3.0  43.0   500.0  54.0
# 35061  35062  2017      2   28    21   23.0  58.0   5.0  61.0   700.0  28.0
# 35062  35063  2017      2   28    22   23.0  53.0   9.0  75.0   900.0  15.0
# 35063  35064  2017      2   28    23   30.0  71.0  11.0  87.0  1200.0   4.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Guanyuan_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Guanyuan.csv")
Guanyuan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0
# 1          2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0
# 2          3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0
# 3          4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0
# 4          5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...    ...   ...
# 35059  35060  2017      2   28    19   13.0  37.0   3.0  36.0  400.0  60.0
# 35060  35061  2017      2   28    20   20.0  43.0   4.0  48.0  500.0  43.0
# 35061  35062  2017      2   28    21   16.0  33.0   5.0  39.0  500.0  50.0
# 35062  35063  2017      2   28    22   11.0  24.0   5.0  47.0  500.0  41.0
# 35063  35064  2017      2   28    23   15.0  27.0   5.0  53.0  600.0  33.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
Gucheng_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Gucheng.csv")
Gucheng_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0  18.0  5.0   NaN  800.0  88.0
# 1          2  2013      3    1     1    6.0  15.0  5.0   NaN  800.0  88.0
# 2          3  2013      3    1     2    5.0  18.0  NaN   NaN  700.0  52.0
# 3          4  2013      3    1     3    6.0  20.0  6.0   NaN    NaN   NaN
# 4          5  2013      3    1     4    5.0  17.0  5.0   NaN  600.0  73.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  58.0  4.0  19.0  500.0  56.0
# 35060  35061  2017      2   28    20   27.0  83.0  6.0  60.0  700.0  26.0
# 35061  35062  2017      2   28    21   22.0  37.0  7.0  52.0  600.0  27.0
# 35062  35063  2017      2   28    22    9.0  23.0  3.0  13.0  400.0  57.0
# 35063  35064  2017      2   28    23   12.0  48.0  5.0  48.0  600.0  28.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Huairou_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Huairou.csv")
Huairou_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    7.0   7.0  3.0   2.0   100.0  91.0
# 1          2  2013      3    1     1    4.0   4.0  3.0   NaN   100.0  92.0
# 2          3  2013      3    1     2    4.0   4.0  NaN   NaN   100.0  91.0
# 3          4  2013      3    1     3    3.0   3.0  3.0   2.0     NaN   NaN
# 4          5  2013      3    1     4    3.0   3.0  7.0   NaN   300.0  86.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...     ...   ...
# 35059  35060  2017      2   28    19   16.0  28.0  2.0  19.0   300.0  95.0
# 35060  35061  2017      2   28    20   21.0  34.0  4.0  24.0   500.0  80.0
# 35061  35062  2017      2   28    21   17.0  33.0  2.0  39.0   900.0  60.0
# 35062  35063  2017      2   28    22   11.0  29.0  3.0  32.0  1400.0  69.0
# 35063  35064  2017      2   28    23   11.0  20.0  2.0  27.0   400.0  77.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Nongzhanguan_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Nongzhanguan.csv")
Nongzhanguan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0
# 1          2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0
# 2          3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0
# 3          4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0
# 4          5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   14.0  21.0  3.0  27.0  400.0  72.0
# 35060  35061  2017      2   28    20   18.0  27.0  3.0  37.0  400.0  59.0
# 35061  35062  2017      2   28    21   15.0  39.0  5.0  50.0  600.0  41.0
# 35062  35063  2017      2   28    22   11.0  35.0  6.0  49.0  500.0  41.0
# 35063  35064  2017      2   28    23   10.0  28.0  7.0  48.0  600.0  39.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
Shunyi_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Shunyi.csv")
Shunyi_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0          1  2013      3    1     0    3.0   6.0   3.0   8.0   300.0  44.0
# 1          2  2013      3    1     1   12.0  12.0   3.0   7.0   300.0  47.0
# 2          3  2013      3    1     2   14.0  14.0   NaN   7.0   200.0  22.0
# 3          4  2013      3    1     3   12.0  12.0   3.0   5.0     NaN   NaN
# 4          5  2013      3    1     4   12.0  12.0   3.0   NaN   200.0  11.0
# ...      ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 35059  35060  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0
# 35060  35061  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0
# 35061  35062  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0
# 35062  35063  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0
# 35063  35064  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Tiantan_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Tiantan.csv")
Tiantan_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0
# 1          2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0
# 2          3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0
# 3          4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0
# 4          5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   20.0  48.0  2.0   NaN  500.0   NaN
# 35060  35061  2017      2   28    20   11.0  34.0  3.0  36.0  500.0   NaN
# 35061  35062  2017      2   28    21   18.0  32.0  4.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   15.0  42.0  5.0  52.0  600.0  44.0
# 35063  35064  2017      2   28    23   15.0  50.0  5.0  68.0  700.0  21.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
Wanliu_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Wanliu.csv")
Wanliu_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0
# 1          2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0
# 2          3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0
# 3          4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN
# 4          5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  27.0  4.0  20.0  300.0  81.0
# 35060  35061  2017      2   28    20   15.0  43.0  6.0  55.0  500.0  45.0
# 35061  35062  2017      2   28    21   13.0  35.0  7.0  48.0  500.0  48.0
# 35062  35063  2017      2   28    22   12.0  31.0  5.0  47.0  500.0  50.0
# 35063  35064  2017      2   28    23    7.0  25.0  6.0  86.0  700.0  11.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
Wanshouxigong_df = pd.read_csv("https://raw.githubusercontent.com/akuana8/air-quality-project/refs/heads/main/PRSA_Data/PRSA_Data_Wanshouxigong.csv")
Wanshouxigong_df
# Out:
#           No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  \
# 0          1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0
# 1          2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0
# 2          3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0
# 3          4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN
# 4          5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0
# ...      ...   ...    ...  ...   ...    ...   ...  ...   ...    ...   ...
# 35059  35060  2017      2   28    19   11.0  32.0  3.0  24.0  400.0  72.0
# 35060  35061  2017      2   28    20   13.0  32.0  3.0  41.0  500.0  50.0
# 35061  35062  2017      2   28    21   14.0  28.0  4.0  38.0  500.0  54.0
# 35062  35063  2017      2   28    22   12.0  23.0  4.0  30.0  400.0  59.0
# 35063  35064  2017      2   28    23   13.0  19.0  4.0  38.0  600.0  49.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# ...

# %% [markdown]
# **Insight:** (Opsional)
# - Dataset air quality terdiri dari data kualitas udara dari 12 stasiun pemantau.
# - Periode pengamatan kualitas udara mencakup Maret 2013 hingga Februari 2017.
# - Dataset memuat informasi berupa polutan udara (PM2.5, PM10, SO2, NO2, CO, O3) serta faktor meteorologi (TEMP, PRES, RAIN, WSPM).

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ####Identifying Air Quality Dataset Problem

# %%
air_quality_df = pd.concat([
    Aotizhongxin_df,
    Changping_df,
    Dingling_df,
    Dongsi_df,
    Guanyuan_df,
    Gucheng_df,
    Huairou_df,
    Nongzhanguan_df,
    Shunyi_df,
    Tiantan_df,
    Wanliu_df,
    Wanshouxigong_df
], ignore_index=True)

# %%
air_quality_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
air_quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
air_quality_df.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
print("Jumlah duplikasi : ", air_quality_df.duplicated().sum())
# Out:
# Jumlah duplikasi :  0

# %%
air_quality_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %% [markdown]
# **Steps to Take:**
# - Memeriksa missing values pada setiap kolom untuk mengidentifikasi data yang hilang.
# - Memeriksa data duplikat untuk memastikan tidak ada redundansi data.
# - Memeriksa type data setiap kolom untuk memastikan kesesuaian dengan jenis data yang disimpan.
# - Menentukan langkah pembersihan data yang diperlukan berdasarkan hasil pemeriksaan.

# %% [markdown]
# **Insight:** (Opsional)
# - Ditemukan missing values pada kolom PM2.5, PM10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM.
# - Kolom CO memiliki jumlah missing values terbanyak, yaitu 20.701 data.
# - Tidak ditemukan data duplikat.
# - Tipe data seluruh kolom sudah sesuai dengan karakteristik data yang disimpan.
# - Tidak ditemukan nilai yang tidak valid berdasarkan hasil pemeriksaan statistik deskriptif.
# - Ditemukan beberapa outlier pada variabel polutan seperti PM2.5, PM10, SO2, CO, dan O3. Outlier akan dipertahankan karena berpotensi merepresentasikan kondisi polusi udara yang sebenarnya.

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Fixing Air Quality Dataset Problem

# %%
num_cols = [
    'PM2.5', 'PM10', 'SO2', 'NO2',
    'CO', 'O3', 'TEMP', 'PRES',
    'DEWP', 'RAIN', 'WSPM'
]

air_quality_df[num_cols] = (
    air_quality_df[num_cols]
    .interpolate(method='linear')
)

air_quality_df['wd'] = (
    air_quality_df['wd']
    .fillna(air_quality_df['wd'].mode()[0])
)

air_quality_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# **Insight:** (Opsional)
# - Seluruh missing values pada kolom numerik berhasil ditangani menggunakan metode interpolasi linear.
# - Missing values pada kolom wd berhasil ditangani menggunakan nilai modus.
# - Tidak ditemukan lagi missing values setelah proses pembersihan data.
# - Outlier tetap dipertahankan karena dapat merepresentasikan kondisi polusi udara ekstrem yang relevan untuk analisis kualitas udara.
# - Dataset telah siap digunakan untuk tahap Exploratory Data Analysis(EDA) dan visualisasi.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Air Quality Dataset

# %%
air_quality_df.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean       11.500000      79.839718     104.910268      15.913090
# std         6.922195      80.950217      92.431422      21.896609
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %%
station_pm25 = (
    air_quality_df
    .groupby('station')['PM2.5']
    .mean()
    .sort_values(ascending=False)
)

station_pm25
# Out:
# station
# Dongsi           86.144243
# Nongzhanguan     85.079472
# Wanshouxigong    85.067548
# Gucheng          84.074802
# Wanliu           83.467612
# Guanyuan         82.897522
# Aotizhongxin     82.540623
# Tiantan          82.033097
# Shunyi           79.437962
# Changping        70.986438
# Huairou          69.501747
# Dingling         66.845557
# Name: PM2.5, dtype: float64

# %%
air_quality_df[
    ['PM2.5','TEMP','PRES','RAIN','WSPM']
].corr()
# Out:
#           PM2.5      TEMP      PRES      RAIN      WSPM
# PM2.5  1.000000 -0.131607  0.019862 -0.014452 -0.271425
# TEMP  -0.131607  1.000000 -0.813312  0.037647  0.032601
# PRES   0.019862 -0.813312  1.000000 -0.060952  0.065400
# RAIN  -0.014452  0.037647 -0.060952  1.000000  0.020975
# WSPM  -0.271425  0.032601  0.065400  0.020975  1.000000

# %% [markdown]
# **Insight:** (Opsional)
# - Rata-rata konsentrasi PM2.5 pada seluruh stasiun adalah 79,84 μg/m³.
# - Nilai maksimum PM2.5 mencapai 999 μg/m³ yang menunjukkan adanya kejadian polusi udara ekstrem selama periode pengamatan.
# - Rata-rata PM10 mencapai 104,91 μg/m³ yang menunjukkan keberadaan partikel udara dalam jumlah yang cukup tinggi.
# - Terdapat variasi tingkat polusi udara antar stasiun pemantauan di Beijing.
# - Hasil korelasi menunjukkan bahwa kecepatan angin (WSPM) memiliki hubungan negatif paling kuat terhadap PM2.5 dibandingkan faktor meteorologi lainnya.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
# Visualisasi Rata-rata PM2.5 per Stasiun

plt.figure(figsize=(12,6))

avg_pm25_station = (
    air_quality_df
    .groupby('station')['PM2.5']
    .mean()
    .sort_values(ascending=False)
)

sns.barplot(
    x=avg_pm25_station.index,
    y=avg_pm25_station.values
)

plt.title('Average PM2.5 Concentration by Station')
plt.xlabel('Station')
plt.ylabel('Average PM2.5')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Visualisasi Heatmap Korelasi
plt.figure(figsize=(8,6))

corr = air_quality_df[
    ['PM2.5','TEMP','PRES','RAIN','WSPM']
].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Between PM2.5 and Meteorological Factors')

plt.show()

# %%
# Visualisasi PM2.5 vs WSPM
sample_df = air_quality_df.sample(
    5000,
    random_state=42
)

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=sample_df,
    x='WSPM',
    y='PM2.5',
    alpha=0.5
)

plt.title('PM2.5 vs Wind Speed')

plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Dongsi memiliki rata-rata konsentrasi PM2.5 tertinggi sebesar 86,14 μg/m³, sedangkan Dingling memiliki rata-rata terendah sebesar 66,85 μg/m³.
# - Sebagian besar stasiun memiliki rata-rata PM2.5 di atas 80 μg/m³, menunjukkan bahwa polusi udara merupakan masalah yang terjadi secara luas di Beijing selama periode pengamatan.
# - Perbedaan konsentrasi PM2.5 antar stasiun menunjukkan adanya variasi tingkat polusi berdasarkan lokasi pemantauan.
# - Wilayah dengan rata-rata PM2.5 tertinggi perlu menjadi prioritas pengendalian polusi udara, seperti Dongsi, Nongzhanguan, Wanshouxigong, Gucheng, Wanliu, Guanyuan, Aotizhongxin, Tiantan, Shunyi.
# - Kecepatan angin (WSPM) memiliki korelasi negatif terbesar terhadap PM2.5 (-0,271).
# - Scatter plot menunjukkan bahwa konsentrasi PM2.5 yang sangat tinggi lebih sering terjadi pada kondisi kecepatan angin rendah.
# - Semakin tinggi kecepatan angin, konsentrasi PM2.5 cenderung menurun karena partikel polutan lebih mudah tersebar ke atmosfer.
# - Suhu memiliki korelasi negatif yang lemah terhadap PM2.5 (-0,132).
# - Curah hujan dan tekanan udara menunjukkan hubungan yang sangat lemah terhadap konsentrasi PM2.5.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
monthly_pm25 = (
    air_quality_df
    .groupby('month')['PM2.5']
    .mean()
    .reset_index()
)

plt.figure(figsize=(10,5))

sns.lineplot(
    data=monthly_pm25,
    x='month',
    y='PM2.5',
    marker='o'
)

plt.title('Average Monthly PM2.5 Concentration')
plt.xlabel('Month')
plt.ylabel('Average PM2.5')

plt.show()

# %% [markdown]
# **Insight:** (Opsional)
# - Konsentrasi PM2.5 menunjukkan pola musiman yang cukup jelas sepanjang tahun.
# - Rata-rata PM2.5 cenderung lebih rendah pada periode musim panas, terutama pada bulan Agustus.
# - Konsentrasi PM2.5 meningkat kembali mulai Oktober dan mencapai puncaknya pada bulan Desember.
# - Pola ini menunjukkan bahwa risiko polusi udara lebih tinggi pada akhir tahun dibandingkan pertengahan tahun.

# %% [markdown]
# ## Conclusion & Recommendation

# %% [markdown]
# - **Conclusion pertanyaan 1:** Berdasarkan analisis rata-rata konsentrasi PM2.5 pada 12 stasiun pemantauan kualitas udara di Beijing selama periode Maret 2013 hingga Februari 2017, ditemukan bahwa Dongsi memiliki rata-rata PM2.5 tertinggi sebesar 86,14 μg/m³, sedangkan Dingling memiliki rata-rata PM2.5 terendah sebesar 66,85 μg/m³. Hasil ini menunjukkan adanya perbedaan tingkat polusi udara antar wilayah di Beijing. Selain itu, sebagian besar stasiun memiliki rata-rata PM2.5 yang relatif tinggi, sehingga pengendalian polusi udara perlu dilakukan secara menyeluruh dengan prioritas pada wilayah dengan konsentrasi PM2.5 tertinggi.
# - **Conclusion pertanyaan 2:** Hasil analisis menunjukkan bahwa faktor meteorologi memiliki hubungan yang berbeda terhadap konsentrasi PM2.5. Kecepatan angin (WSPM) memiliki korelasi negatif terbesar terhadap PM2.5 dengan nilai -0,271, yang mengindikasikan bahwa peningkatan kecepatan angin cenderung menurunkan konsentrasi PM2.5. Temuan ini juga didukung oleh visualisasi scatter plot yang menunjukkan bahwa konsentrasi PM2.5 yang tinggi lebih sering terjadi pada kondisi kecepatan angin rendah. Sementara itu, suhu udara memiliki hubungan negatif yang lebih lemah, sedangkan tekanan udara dan curah hujan menunjukkan hubungan yang sangat lemah terhadap konsentrasi PM2.5.

# %% [markdown]
# **Rekomendasi Action Item:**
# - Memprioritaskan pengendalian emisi pada wilayah sekitar stasiun Dongsi, Nongzhanguan, Wanshouxigong, Gucheng, Wanliu, Guanyuan, Aotizhongxin, Tiantan, Shunyi karena memiliki rata-rata PM2.5 tinggi selama periode pengamatan.
#
# - Meningkatkan frekuensi pemantauan kualitas udara menjelang akhir tahun, terutama pada bulan Oktober hingga Desember, karena periode tersebut menunjukkan peningkatan konsentrasi PM2.5.
#
# - Memanfaatkan informasi kecepatan angin sebagai indikator pendukung dalam sistem peringatan dini kualitas udara karena memiliki hubungan paling kuat terhadap konsentrasi PM2.5.
#
# - Melakukan evaluasi terhadap sumber emisi utama seperti transportasi, industri, dan pembakaran bahan bakar pada wilayah dengan tingkat PM2.5 tinggi.
#
# - Menyusun strategi mitigasi yang lebih terfokus pada lokasi dan periode dengan risiko polusi tinggi agar upaya pengendalian kualitas udara dapat dilakukan secara lebih efektif.

# %% [markdown]
# ###Clustering

# %% [markdown]
# Analisis clustering dilakukan untuk mengelompokkan stasiun pemantauan kualitas udara berdasarkan rata-rata konsentrasi PM2.5. Pengelompokan ini bertujuan untuk membantu mengidentifikasi wilayah dengan tingkat polusi udara tinggi, sedang, dan rendah sehingga dapat mendukung penentuan prioritas dalam pengendalian polusi udara.

# %%
station_pm25 = (
    air_quality_df
    .groupby('station')['PM2.5']
    .mean()
    .reset_index()
)

def pollution_level(pm25):
    if pm25 >= 85:
        return "High"
    elif pm25 >= 75:
        return "Medium"
    else:
        return "Low"

station_pm25["pollution_level"] = (
    station_pm25["PM2.5"]
    .apply(pollution_level)
)

station_pm25
# Out:
#           station      PM2.5 pollution_level
# 0    Aotizhongxin  82.540623          Medium
# 1       Changping  70.986438             Low
# 2        Dingling  66.845557             Low
# 3          Dongsi  86.144243            High
# 4        Guanyuan  82.897522          Medium
# 5         Gucheng  84.074802          Medium
# 6         Huairou  69.501747             Low
# 7    Nongzhanguan  85.079472            High
# 8          Shunyi  79.437962          Medium
# 9         Tiantan  82.033097          Medium
# 10         Wanliu  83.467612          Medium
# 11  Wanshouxigong  85.067548            High

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=station_pm25,
    x='pollution_level',
    order=['Low','Medium','High']
)

plt.title('Station Pollution Level Clustering')
plt.show()

# %% [markdown]
# **Insight:**
# - Sebanyak 3 stasiun termasuk dalam kategori High Pollution, yaitu Dongsi, Nongzhanguan, dan Wanshouxigong.
# - Sebanyak 6 stasiun termasuk dalam kategori Medium Pollution.
# - Sebanyak 3 stasiun termasuk dalam kategori Low Pollution, yaitu Changping, Dingling, dan Huairou.
# - Hasil clustering menunjukkan bahwa sebagian besar stasiun berada pada kategori Medium hingga High, yang mengindikasikan bahwa polusi PM2.5 masih menjadi isu penting di berbagai wilayah Beijing.
# - Kelompok High Pollution dapat dijadikan prioritas utama dalam penyusunan kebijakan pengendalian kualitas udara.

# %% [markdown]
# #### Export and Download

# %%
air_quality_df.to_csv(
    "main_data.csv",
    index=False
)

# %%
from google.colab import files
files.download("main_data.csv")
